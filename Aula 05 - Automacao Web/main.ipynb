# %% [markdown]
# # 🚀 **Aula 05: Parte 02 - Desenvolvendo e trabalhando com bots na web como RPA utilizando Selenium**

# %% [markdown]
# ## Nesta aula iremos estar desenvolvendo alguns bots web que realizam tarefas manuais em sites na web, como por exemplo preenchimento automatico de formularios e login automatico em websites, além de entender sobre entender a principal ferramenta para realizarmos essas tarefas, a ferramenta de testes e automação **Selenium**.
# ---

# %% [markdown]
# # **1. O que é Selenium?**  ⚡

# %% [markdown]
# <img src="https://www.meme-arsenal.com/memes/bc08a47bc3f8632706cd9e94b2221ce9.jpg" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# ### Selenium é uma ferramenta de código aberto que automatiza os navegadores da web. Ele fornece uma interface única que permite escrever scripts de teste em linguagens de programação como Ruby, Java, NodeJS, PHP, Perl, Python e C#, entre outras.

# %% [markdown]
# ### Em automação Web podemos considerar que Selenium é um conjunto de bibliotecas que nos ajudam a automatizar e interagir com os navegadores.

# %% [markdown]
# ### No entanto, selenium vai muito além disso. Selenium também é utilizado para realizar testes automatizados de aplicações, muito usado em projetos que incluem criações de API, Integral para Integração/Entrega Contínua (CI/CD), testes de performance, entre outros.
#
# ### Tambem podemos utilizar selenium para realizar web scraping em paginas na web de conteudio **Dinâmico**.

# %% [markdown]
# ## **1.1 Por que selenium?**

# %% [markdown]
# ### Open Source -> GRATUITO
# - Suporta diferentes tipos de navegadores
# - Suporta várias linguagens de programação diferentes
# - Enorme comunidade por trás dele tantas respostas para quaisquer problemas/perguntas
# - Pode ser executado em diferentes sistemas operacionais, como: Mac, Windows, Linux etc.

# %% [markdown]
# # **2. Instalação**  ⚡

# %% [markdown]
# ## **2.1 Instalando bibliotecas**

# %% [markdown]
# ### Para começarmos, iremos instalar nossa biblioteca utilizando o *pip*

# %%
# !pip3 install selenium

# %% [markdown]
# ## **2.2 Opção 1: Instalando drivers manualmente**

# %% [markdown]
# ### Para utilizarmos o Selenium é necessário um driver para fazer interface com o navegador escolhido.
# ### Para nosso treinamento, iremos utilizar o navegador Google Chrome.
# ### O Firefox, por exemplo, requer o geckodriver, que precisa ser instalado antes que os exemplos abaixo possam ser executados. Certifique-se de que está no seu PATH.
# ### A não observância desta etapa causará o erro selenium.common.exceptions.WebDriverException: Mensagem: o executável 'geckodriver' precisa estar no PATH.
# ### Os navegadores suportados terão seus próprios drivers disponíveis. Seguem links para alguns dos drivers de navegador mais populares.
#
# - [Chrome](https://sites.google.com/chromium.org/driver/)
# - [Edge](https://developer.microsoft.com/en-us/microsoft-edge/tools/webdriver/)
# - [Firefox](https://github.com/mozilla/geckodriver/releases)
# - [Safari](https://webkit.org/blog/6900/webdriver-support-in-safari-10/)
#
# ### **Obs**: Certifique-se de baixar a versão correspondente ao seu navegador no momento de realizar o download do driver.

# %% [markdown]
# <img src="../images/drive_version.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# ### Para obter mais informações sobre a instalação do driver, consulte a documentação oficial, que pode ser encontrada nas referências.

# %% [markdown]
# ## **2.3 Opção 2: Instalando drivers de forma automática**

# %% [markdown]
# ### Para o passo anterior, é necessáro verificar a versão do navegador, realizar o download do driver compátivel, salvar-lo em um diretório e indicar o caminho absoluto dentro do script.
#
# ### Existe outra maneira de utilizarmos os drivers de navegadores de forma automatica com a biblioteca *webdriver-manager*, que automaticamente realiza este trabalho manual, salvando o driver em um diretorio de nossa máquina.

# %%
! pip install webdriver-manager

# %% [markdown]
# # **3. Exemplo simples**  ⚡

# %% [markdown]
# ## **3.1 Importando os pacotes**

# %% [markdown]
# ### Iniciaremos importando os pacotes necessários

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep

# %% [markdown]
# ## **3.2 Abrindo uma pagina na internet**

# %% [markdown]
# ### Vamos abrir o site da Amazon e procurar por algum produto

# %%
# Instala um novo driver do Chrome caso não exista
driver = webdriver.Chrome(ChromeDriverManager().install())
# Abre o site
driver.get("https://www.amazon.com")
# Procura o campo de busca
busca_box = driver.find_element_by_xpath('//*[@id="twotabsearchtextbox"]')
# Digita o termo de busca
produto = input("Digite o produto que deseja buscar: ")
# Limpa o campo de busca antes de digitar o produto
busca_box.clear()
# Envia o produto para o campo de busca
busca_box.send_keys(produto)
# Aperta enter
busca_box.send_keys(Keys.RETURN)

# %% [markdown]
# # **4. Mini projeto 01 - Preenchendo formulário automaticamente na internet**  ⚡

# %% [markdown]
# ### Para este mini projeto iremos preencher um formulário na internet de forma prática usando Python e Selenium.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.select import Select
from threading import Thread
from webdriver_manager.chrome import ChromeDriverManager

class AutoFormBot():
    def __init__(self):
        # Todo o bloco sera executado quando o objeto for criado
        options = Options()
        # Caso queira que o driver abra o site em modo headless
        # options.add_argument("--headless")
        website = "https://iqssdss2020.pythonanywhere.com/tutorial/form/search"
        self.driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
        self.driver.get(website)
        self.driver.maximize_window()
        ################################################################
        
    def fill_field_name(self, name) -> None:
        field_name = self.driver.find_element_by_xpath('//*[@id="search_name"]')
        field_name.send_keys(name)
        
    def select_field_grade(self) -> None:
        # Usaremos o módulo Select para selecionar o campo de grade
        field_grade = Select(self.driver.find_element_by_xpath('//*[@id="search_grade"]'))
        # Espera 10 segundos até que o campo apareça
        self.driver.implicitly_wait(10)
        # Como usamos o método Select, podemos selecionar o valor desejado pelo texto do campo 
        field_grade.select_by_visible_text("5")
        
    def select_page_size(self, page_size=10) -> None:
        # Como os campos variam de 5, 10 e 15 podemos atribuir uma lista de valores exata para o campo
        page_size_list = [5, 10, 15]
        if page_size not in page_size_list:
            print("O valor passado não é válido")
            return None
        field_page_size = self.driver.find_element_by_xpath(f'//*[@id="p{page_size}"]')
        field_page_size.click()
        
    def accept_privacy_policy(self) -> None:
        field_privacy_policy = self.driver.find_element_by_xpath('//*[@id="privacypolicy"]')
        field_privacy_policy.click()
        
    def accept_terms_and_conditions(self) -> None:
        field_terms_and_conditions = self.driver.find_element_by_xpath('//*[@id="termsconditions"]')
        field_terms_and_conditions.click()
        
    def select_search_button(self) -> None:
        field_search_button = self.driver.find_element_by_xpath('//*[@id="search"]')
        self.driver.implicitly_wait(10)
        field_search_button.click()
        
    def run_all(self) -> None:
        """
        Function to run all the functions in parallel
        
        """
        if __name__ == "__main__":
            Thread(target=self.fill_field_name, args=("Teste",)).start()
            Thread(target=self.select_field_grade).start()
            Thread(target=self.select_page_size, args=(10,)).start()
            Thread(target=self.accept_privacy_policy).start()
            Thread(target=self.accept_terms_and_conditions).start()
            self.driver.implicitly_wait(10)
            self.select_search_button()

bot = AutoFormBot()
bot.run_all()

# %% [markdown]
# ### No exemplo acima preenchemos o formulario automaticamente, campo a campo. E se quisessemos preencher todos os campos de uma só vez?

# %% [markdown]
# ### Threads! Podemos acrescentar um novo método em nossa classe que preenche todos os campos de uma só vez.

# %% [markdown]
# # **5. Mini projeto 02 - Criando novas contas automaticamentes em site de ecommerce**  ⚡

# %% [markdown]
# ### Para este projeto iremos estar criando novas contas automaticamente em um site de ecommerce, gerando registros aleatorios e salvando os em uma planilha do excel.

# %% [markdown]
# ### Para isso, iremos gerar alguns dados falsos com a biblioteca *Faker*, e a biblioteca *pandas* para salvar os registros em uma planilha do excel

# %%
# !pip3 install Faker
# !pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Faker
#   Downloading Faker-15.1.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 374.0 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.4 in /home/antonio_costa/.local/lib/python3.10/site-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/antonio_costa/.local/lib/python3.10/site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Installing collected packages: Faker
# Successfully installed Faker-15.1.1
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/antonio_costa/.local/lib/python3.10/site-packages (1.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/antonio_costa/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /home/antonio_costa/.local/lib/python3.10/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: pytz>=2020.1 in /home/antonio_costa/.local/lib/python3.10/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /home/antonio_costa/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ## **5.1 Gerando dados aleatorios**

# %%
from faker import Faker


def gera_dados(num_registros: int) -> list[dict[str, str]]:
    
    # Instancia o Faker
    fake = Faker()

    registros = []
    for _ in range(num_registros):
        
        name = fake.name()
        first_name = name.split()[0]
        second_name = name.split()[1]
        email = fake.email()
        telephone = fake.phone_number()
        password = fake.password()
        
        # Salvando dados em uma lista de dicionarios
        registros.append(
            {
                "first_name": first_name,
                "second_name": second_name,
                "email": email,
                "telephone": telephone,
                "password": password
            }
        )
        
    return registros

# %% [markdown]
# ### Vamos printar nosso resultado com mais clareza com ajuda da biblioteca json

# %%
import json

registros = gera_dados(num_registros=100)
pretty_registros = json.dumps(registros, indent=4)
print(pretty_registros)
# Out:
# [
#     {
#         "first_name": "Jennifer",
#         "second_name": "Bradley",
#         "email": "davidmark@example.net",
#         "telephone": "536.846.6723",
#         "password": "w!D8YoitQ*"
#     },
#     {
#         "first_name": "Bryan",
#         "second_name": "Mendez",
#         "email": "tweiss@example.com",
#         "telephone": "+1-818-086-4478x411",
#         "password": "(O9n6VMn5X"
#     },
#     {
#         "first_name": "Lori",
#         "second_name": "Warren",
#         "email": "tbaldwin@example.net",
#         "telephone": "001-017-413-4702x142",
#         "password": "_Q3VV2Uu9n"
#     },
#     {
#         "first_name": "Whitney",
#         "second_name": "Smith",
#         "email": "destinyjenkins@example.org",
#         "telephone": "001-311-995-2027x0774",
#         "password": "%9cU5cUqz+"
#     },
#     {
#         "first_name": "Kevin",
#         "second_name": "Boyd",
#         "email": "sandrews@example.net",
#         "telephone": "8126332155",
#         "password": "w0HN#5A(%l"
#     },
#     {
#         "first_name": "Robert",
#         "second_name": "Wells",
#         "email": "sarah23@example.org",
#         "telephone": "079-979-2172",
#         "password": "&4QRIaiesS"
#     },
#     {
#         "first_name": "Greg",
#         "second_name": "Hill",
#         "email": "dfowler@example.net",
#         "telephone": "720-073-0932",
#         "password": "uvTCMqdz^8"
#     },
#     {
#         "first_name": "Caleb",
#         "second_name": "King",
#         "email": "amber69@example.net",
#         "telephone": "(958)910-0176",
#         "password": "NE!lyWxg_5"
#     },
#     {
#         "first_name": "Sabrina",
#         "second_name": "Avila",
#         "email": "shane91@example.net",
#         "telephone": "(415)890-8556x666",
#         "password": "@T4vcOpi&A"
#     },
#     {
#         "first_name": "Ricardo",
#         "second_name": "Oconnor",
#         "email": "chrislewis@example.net",
#         "telephone": "543.552.1154",
#         "password": "_L^6R6KepF"
#     },
#     {
#         "first_name": "Alex",
#         "second_name": "Young",
#         "email": "robertlucas@example.org",
#         "telephone": "016.030.6400",
#         "password": "5D9JkIpE)b"
#     },
#     {
#         "first_name": "Erik",
#         "second_name": "Walsh",
#         "email": "jensenblake@example.net",
#         "telephone": "367-519-4759x51391",
#         "password": "8)xVZcPv$A"
#     },
#     {
#         "first_name": "Charles",
#         "second_name": "Henry",
#         "email": "bryan01@example.org",
#         "telephone": "489-069-6383x175",
#         "password": "#v0PLYj21E"
#     },
#     {
#         "first_name": "Sherry",
#         "second_name": "Goodman",
#         "email": "danamiller@example.net",
#         "telephone": "173-391-3829",
#         "password": "Z+m2XFmhYu"
#     },
#     {
#         "first_name": "Melvin",
#         "second_name": "Hanson",
#         "email": "bradleygeorge@example.org",
#         "telephone": "361-210-7386x915",
#         "password": "@Ot83SNiB!"
#     },
#     {
#         "first_name": "Frederick",
#         "second_name": "Coffey",
#         "email": "tina50@example.org",
#         "telephone": "001-139-343-3839",
#         "password": "E16Tw%xy(s"
#     },
#     {
#         "first_name": "Brianna",
#         "second_name": "Ramirez",
#         "email": "zflores@example.org",
#         "telephone": "(398)889-0690x9652",
#         "password": "@AS9vLa6q1"
#     },
#     {
#         "first_name": "Mr.",
#         "second_name": "Brendan",
#         "email": "devingomez@example.net",
#         "telephone": "696-809-8730x07510",
#         "password": "^S6RHc6r0Q"
#     },
#     {
#         "first_name": "Keith",
#         "second_name": "Duncan",
#         "email": "loribarber@example.com",
#         "telephone": "356.884.2965",
#         "password": "FfwX*hUv*5"
#     },
#     {
#         "first_name": "Cynthia",
#         "second_name": "Roberts",
#         "email": "omooney@example.org",
#         "telephone": "153-293-7356",
#         "password": "k^d7qkCr*("
#     },
#     {
#         "first_name": "Megan",
#         "second_name": "Bryant",
#         "email": "ericcannon@example.com",
#         "telephone": "548.127.1261",
#         "password": "8zS(5rhY)D"
#     },
#     {
#         "first_name": "Joseph",
#         "second_name": "Harrison",
#         "email": "hurstmario@example.com",
#         "telephone": "996.013.5800",
#         "password": "0D5vX#c&$r"
#     },
#     {
#         "first_name": "Samantha",
#         "second_name": "Riley",
#         "email": "tinahill@example.com",
#         "telephone": "(686)400-8866x75707",
#         "password": "d1ZDnYu9@i"
#     },
#     {
#         "first_name": "Joel",
#         "second_name": "Simmons",
#         "email": "deborahbailey@example.org",
#         "telephone": "(187)783-7692",
#         "password": "+xf9LLjhfn"
#     },
#     {
#         "first_name": "Ashley",
#         "second_name": "Thompson",
#         "email": "ashleypotter@example.net",
#         "telephone": "443.127.8256x2843",
#         "password": "%19^6Kp()Q"
#     },
#     {
#         "first_name": "Valerie",
#         "second_name": "Miller",
#         "email": "derrickmorgan@example.com",
#         "telephone": "+1-719-304-4929",
#         "password": "6%mnOHui^&"
#     },
#     {
#         "first_name": "Nicholas",
#         "second_name": "Hernandez",
#         "email": "chernandez@example.net",
#         "telephone": "711-300-6476x026",
#         "password": "%Tfxi0gzJ6"
#     },
#     {
#         "first_name": "Courtney",
#         "second_name": "Griffith",
#         "email": "shawjudith@example.org",
#         "telephone": "(439)550-9784",
#         "password": "*^+)3Sooiu"
#     },
#     {
#         "first_name": "Claire",
#         "second_name": "Crawford",
#         "email": "brenda16@example.com",
#         "telephone": "001-532-001-7590x799",
#         "password": "+ArCldU)_3"
#     },
#     {
#         "first_name": "Linda",
#         "second_name": "Moon",
#         "email": "rrivera@example.com",
#         "telephone": "829-733-5126x203",
#         "password": "#5IB%bvUu1"
#     },
#     {
#         "first_name": "Amanda",
#         "second_name": "Young",
#         "email": "joshua70@example.com",
#         "telephone": "6789318067",
#         "password": "ykl3_1NUc*"
#     },
#     {
#         "first_name": "Shane",
#         "second_name": "Wilson",
#         "email": "mccannshannon@example.org",
#         "telephone": "001-766-557-5493x90535",
#         "password": "osNxT^dR)5"
#     },
#     {
#         "first_name": "Laura",
#         "second_name": "Morton",
#         "email": "brian01@example.com",
#         "telephone": "305-139-3294",
#         "password": "1GH%lcY1+7"
#     },
#     {
#         "first_name": "Brandon",
#         "second_name": "Carter",
#         "email": "deanboyd@example.com",
#         "telephone": "036.122.8828",
#         "password": "+ie$Ok@R_7"
#     },
#     {
#         "first_name": "Erica",
#         "second_name": "Gonzales",
#         "email": "murphydaniel@example.org",
#         "telephone": "542-157-9229x5305",
#         "password": "tt0%YN_x(+"
#     },
#     {
#         "first_name": "Lori",
#         "second_name": "Spencer",
#         "email": "amanda57@example.com",
#         "telephone": "918.236.9415",
#         "password": "Q+4#)1Xbmw"
#     },
#     {
#         "first_name": "John",
#         "second_name": "Sanders",
#         "email": "palmerian@example.com",
#         "telephone": "(760)589-8266",
#         "password": "_94zN_#oBs"
#     },
#     {
#         "first_name": "Andrew",
#         "second_name": "Murillo",
#         "email": "tinaholt@example.com",
#         "telephone": "246.796.6508",
#         "password": "!6IfcvBD2C"
#     },
#     {
#         "first_name": "Kevin",
#         "second_name": "Larson",
#         "email": "cassandraevans@example.org",
#         "telephone": "877.440.7325x139",
#         "password": "f57KWt8wG("
#     },
#     {
#         "first_name": "Tiffany",
#         "second_name": "Rivera",
#         "email": "courtney17@example.org",
#         "telephone": "+1-426-327-9516x79095",
#         "password": "a_0v2IbNgI"
#     },
#     {
#         "first_name": "Andrew",
#         "second_name": "Huber",
#         "email": "wardthomas@example.net",
#         "telephone": "987-711-8043x148",
#         "password": "#A7Z@Xi6aM"
#     },
#     {
#         "first_name": "Jasmine",
#         "second_name": "Fuller",
#         "email": "robert76@example.net",
#         "telephone": "2265904352",
#         "password": "%#RFcnunt3"
#     },
#     {
#         "first_name": "Jasmine",
#         "second_name": "Woodward",
#         "email": "allenjohn@example.org",
#         "telephone": "(924)275-6284x54814",
#         "password": "zgpnQmKR%7"
#     },
#     {
#         "first_name": "William",
#         "second_name": "Brady",
#         "email": "jacqueline02@example.com",
#         "telephone": "957.808.1536x815",
#         "password": "_PIZ)cMj)7"
#     },
#     {
#         "first_name": "Patrick",
#         "second_name": "Lawrence",
#         "email": "aholmes@example.org",
#         "telephone": "(496)032-2171x107",
#         "password": "%3dycEBotC"
#     },
#     {
#         "first_name": "Jennifer",
#         "second_name": "Torres",
#         "email": "qjackson@example.com",
#         "telephone": "+1-138-738-8391x7006",
#         "password": "7y8_E(XuB("
#     },
#     {
#         "first_name": "Diana",
#         "second_name": "Vaughn",
#         "email": "mannelizabeth@example.org",
#         "telephone": "603-947-6842",
#         "password": "%1b*9iEe$$"
#     },
#     {
#         "first_name": "Cory",
#         "second_name": "Hughes",
#         "email": "michaelbauer@example.com",
#         "telephone": "851.473.9197",
#         "password": "k)2Pf9zp^I"
#     },
#     {
#         "first_name": "Christian",
#         "second_name": "Martin",
#         "email": "garciaaaron@example.org",
#         "telephone": "454-272-1792",
#         "password": "#4GjJzXm!2"
#     },
#     {
#         "first_name": "Wayne",
#         "second_name": "Hill",
#         "email": "garciadawn@example.net",
#         "telephone": "(183)494-4650",
#         "password": "eM50KsUA(6"
#     },
#     {
#         "first_name": "Dr.",
#         "second_name": "Ryan",
#         "email": "rodriguezanna@example.com",
#         "telephone": "382.541.1314",
#         "password": ")2KXTFzsml"
#     },
#     {
#         "first_name": "Ashley",
#         "second_name": "Powell",
#         "email": "ujohnson@example.org",
#         "telephone": "+1-071-365-7962x45476",
#         "password": "i!VoR5Ors)"
#     },
#     {
#         "first_name": "William",
#         "second_name": "Jones",
#         "email": "hgarcia@example.com",
#         "telephone": "+1-454-281-8138x0565",
#         "password": "@9!_FUfDoB"
#     },
#     {
#         "first_name": "Jonathan",
#         "second_name": "Gonzalez",
#         "email": "xbaker@example.net",
#         "telephone": "331-299-6971",
#         "password": "Rx0Zk_34@N"
#     },
#     {
#         "first_name": "Danielle",
#         "second_name": "Hernandez",
#         "email": "wilsonkevin@example.com",
#         "telephone": "(309)344-4918x514",
#         "password": "+5WbzaPVPX"
#     },
#     {
#         "first_name": "Jordan",
#         "second_name": "Anderson",
#         "email": "alec13@example.org",
#         "telephone": "+1-378-091-2194",
#         "password": "0YLe6Gtc!9"
#     },
#     {
#         "first_name": "Cheryl",
#         "second_name": "Barnes",
#         "email": "robertboyd@example.org",
#         "telephone": "(676)421-6507x108",
#         "password": "ge21yVWbR_"
#     },
#     {
#         "first_name": "Shane",
#         "second_name": "Smith",
#         "email": "christine07@example.org",
#         "telephone": "500.536.6517x643",
#         "password": "a+e1KGAln7"
#     },
#     {
#         "first_name": "Danny",
#         "second_name": "Peterson",
#         "email": "delacruzjames@example.net",
#         "telephone": "923-125-2113",
#         "password": "9NGjr7gP(U"
#     },
#     {
#         "first_name": "Dakota",
#         "second_name": "Wells",
#         "email": "heathhaley@example.com",
#         "telephone": "001-397-462-1172x173",
#         "password": "t)I8Oh#8V_"
#     },
#     {
#         "first_name": "Angela",
#         "second_name": "Mayo",
#         "email": "haleydaniel@example.com",
#         "telephone": "9539727651",
#         "password": "@(dXcHd(q6"
#     },
#     {
#         "first_name": "Shirley",
#         "second_name": "Arnold",
#         "email": "richbrittany@example.net",
#         "telephone": "001-165-423-4512",
#         "password": "$&1EmmZeD#"
#     },
#     {
#         "first_name": "Caitlin",
#         "second_name": "Lambert",
#         "email": "uterry@example.com",
#         "telephone": "(650)967-7457x473",
#         "password": "%oYmUdH($6"
#     },
#     {
#         "first_name": "Mrs.",
#         "second_name": "Brittany",
#         "email": "robert37@example.org",
#         "telephone": "+1-896-977-4748x340",
#         "password": "_8sHzYj*O%"
#     },
#     {
#         "first_name": "Edward",
#         "second_name": "Petty",
#         "email": "tiffanyburnett@example.com",
#         "telephone": "(323)599-3841",
#         "password": "&$5FvY9%^P"
#     },
#     {
#         "first_name": "Sheila",
#         "second_name": "Kane",
#         "email": "stephaniejohnson@example.net",
#         "telephone": "+1-221-082-2373x043",
#         "password": "m^8Alebs!9"
#     },
#     {
#         "first_name": "Zachary",
#         "second_name": "Acosta",
#         "email": "lisamcintosh@example.net",
#         "telephone": "(721)344-4303x563",
#         "password": "*ERJa7@_23"
#     },
#     {
#         "first_name": "John",
#         "second_name": "Reeves",
#         "email": "carol81@example.net",
#         "telephone": "024-447-8797x34364",
#         "password": "0bWPiGpE%3"
#     },
#     {
#         "first_name": "Rhonda",
#         "second_name": "Stephens",
#         "email": "lynnyoung@example.net",
#         "telephone": "(204)726-0110",
#         "password": "m#5TJmg3mt"
#     },
#     {
#         "first_name": "Jesse",
#         "second_name": "Murphy",
#         "email": "daviladerrick@example.com",
#         "telephone": "(967)344-4461",
#         "password": "&!7SM*eXBI"
#     },
#     {
#         "first_name": "Andrew",
#         "second_name": "Taylor",
#         "email": "levinevictoria@example.com",
#         "telephone": "8819047403",
#         "password": "J%SK@thA)8"
#     },
#     {
#         "first_name": "Alan",
#         "second_name": "Medina",
#         "email": "kendra22@example.net",
#         "telephone": "293-693-4677",
#         "password": "#e51eEWa^9"
#     },
#     {
#         "first_name": "Randy",
#         "second_name": "Anderson",
#         "email": "blacksarah@example.net",
#         "telephone": "(690)834-5078",
#         "password": "5oWCMPvo&h"
#     },
#     {
#         "first_name": "Joe",
#         "second_name": "Hickman",
#         "email": "jennifertaylor@example.com",
#         "telephone": "223.297.6179x67911",
#         "password": "%fUS&8LcOJ"
#     },
#     {
#         "first_name": "William",
#         "second_name": "Barron",
#         "email": "kelseyfields@example.net",
#         "telephone": "718-565-8410",
#         "password": "WQMK3XdKS!"
#     },
#     {
#         "first_name": "Melanie",
#         "second_name": "Lopez",
#         "email": "raymondchristopher@example.com",
#         "telephone": "505.567.9026",
#         "password": ")vEhQk6!2y"
#     },
#     {
#         "first_name": "Rachel",
#         "second_name": "Lloyd",
#         "email": "christopherlang@example.com",
#         "telephone": "001-360-581-9363x4163",
#         "password": "6gM__M#+!n"
#     },
#     {
#         "first_name": "Noah",
#         "second_name": "Davies",
#         "email": "mariadixon@example.org",
#         "telephone": "734-161-5628x56485",
#         "password": "5^zZ9F!wzN"
#     },
#     {
#         "first_name": "Ryan",
#         "second_name": "Williams",
#         "email": "rivaskarina@example.com",
#         "telephone": "001-696-609-7600x2641",
#         "password": "15IwtRg&*S"
#     },
#     {
#         "first_name": "Deborah",
#         "second_name": "Smith",
#         "email": "youngvictoria@example.com",
#         "telephone": "088.340.1715x857",
#         "password": "&+!g2AkUFQ"
#     },
#     {
#         "first_name": "Paul",
#         "second_name": "Dawson",
#         "email": "cassandra84@example.net",
#         "telephone": "591.197.5779",
#         "password": ")cO8KuH*a5"
#     },
#     {
#         "first_name": "Sarah",
#         "second_name": "Valdez",
#         "email": "mollysimmons@example.org",
#         "telephone": "(903)532-1037",
#         "password": "J_GA3MxG*q"
#     },
#     {
#         "first_name": "Troy",
#         "second_name": "Smith",
#         "email": "crusso@example.org",
#         "telephone": "941.243.4616x337",
#         "password": "$+6xMth#%a"
#     },
#     {
#         "first_name": "Gabrielle",
#         "second_name": "Woods",
#         "email": "tonylara@example.com",
#         "telephone": "352.290.1747x9711",
#         "password": "O_8@NVry@U"
#     },
#     {
#         "first_name": "Lisa",
#         "second_name": "Browning",
#         "email": "stephensonjason@example.com",
#         "telephone": "736.823.6003x225",
#         "password": "h@z)84ZlSP"
#     },
#     {
#         "first_name": "Amanda",
#         "second_name": "Jones",
#         "email": "stevenali@example.com",
#         "telephone": "001-853-018-0157x583",
#         "password": "*dJYL5Jl99"
#     },
#     {
#         "first_name": "Morgan",
#         "second_name": "Duncan",
#         "email": "vfuller@example.com",
#         "telephone": "+1-320-456-6969",
#         "password": "K37r*Y)l_P"
#     },
#     {
#         "first_name": "Elizabeth",
#         "second_name": "Dixon",
#         "email": "scottcrawford@example.net",
#         "telephone": "(422)963-4718x7687",
#         "password": "@ht7QlxjMn"
#     },
#     {
#         "first_name": "Lisa",
#         "second_name": "Briggs",
#         "email": "brandonhooper@example.net",
#         "telephone": "019.254.6269",
#         "password": "iapT0vVZ@8"
#     },
#     {
#         "first_name": "Jonathan",
#         "second_name": "Evans",
#         "email": "ritavega@example.com",
#         "telephone": "109.394.7359x39686",
#         "password": "#d!9%6)iV3"
#     },
#     {
#         "first_name": "Sean",
#         "second_name": "Smith",
#         "email": "megan90@example.com",
#         "telephone": "106-180-7976",
#         "password": ")bO8Wgmtd3"
#     },
#     {
#         "first_name": "Wendy",
#         "second_name": "Cooke",
#         "email": "xfuller@example.net",
#         "telephone": "(367)400-2665",
#         "password": "%0jFMDPhx*"
#     },
#     {
#         "first_name": "Debra",
#         "second_name": "Patterson",
#         "email": "payneshelly@example.org",
#         "telephone": "572.666.1917x25995",
#         "password": ")7)4oKs5+Z"
#     },
#     {
#         "first_name": "Mr.",
#         "second_name": "Chad",
#         "email": "brendawilson@example.net",
#         "telephone": "156-325-4905x671",
#         "password": "$n@#e2RxxF"
#     },
#     {
#         "first_name": "Wendy",
#         "second_name": "Lee",
#         "email": "vickiebaker@example.org",
#         "telephone": "(817)816-4563",
#         "password": "@7ECDCzlH0"
#     },
#     {
#         "first_name": "Robert",
#         "second_name": "Hernandez",
#         "email": "christine01@example.org",
#         "telephone": "001-859-181-5187x356",
#         "password": "DRWJneai*3"
#     },
#     {
#         "first_name": "Destiny",
#         "second_name": "Mahoney",
#         "email": "dominiqueking@example.net",
#         "telephone": "956.784.1256",
#         "password": "$KBl6PJsJ1"
#     },
#     {
#         "first_name": "Jonathan",
#         "second_name": "Wilson",
#         "email": "brittany57@example.net",
#         "telephone": "(136)084-9961",
#         "password": "NwMcv0Br%6"
#     },
#     {
#         "first_name": "Michael",
#         "second_name": "Williams",
#         "email": "jcabrera@example.net",
#         "telephone": "727.641.9936x4646",
#         "password": "@83H(hMT^("
#     },
#     {
#         "first_name": "Kimberly",
#         "second_name": "Ruiz",
#         "email": "erica34@example.net",
#         "telephone": "442-439-3949x759",
#         "password": "+6Q!JyU(%0"
#     }
# ]

# %% [markdown]
# ## **5.2 Salvando registros em uma planilha excel**

# %% [markdown]
# ### Agora que ja possuimos os registros, iremos salvar os registros em uma planilha do excel

# %%
import pandas as pd

def data_to_excel(data: list[dict[str, str]]) -> None:
    df = pd.DataFrame(data)
    df.to_excel("dados.xlsx", index=False)

# %% [markdown]
# ### Para gerar os dados para uma planilha, necessitamos da biblioteca *openpyxl* instalada.

# %%
# !pip3 install openpyxl

# %% [markdown]
# ### Se executarmos o bloco anterior novamente sera gerada uma planilha com todos os dados gerados

# %% [markdown]
# ## **5.3 Criando nosso bot**

# %% [markdown]
# ### Agora que ja criamos as funções que geram os dados aleatórios e ja temos eles salvos em uma planilha do excel, esta na hora de criarmos nosso bot

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.by import By
from threading import Thread
from time import sleep
from webdriver_manager.chrome import ChromeDriverManager


class EcommerceBot():
    def __init__(self, headless: bool = False) -> None:
        
        
        options = Options()
        if headless:
            # Abre o navegador em modo headless
            options.add_argument("--headless")
            
        website = 'https://ecommerce-playground.lambdatest.io/index.php?route=account/register'
        self.driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
        self.driver.get(website)
        
    def fill_field_name(self, name) -> None:
        first_name = self.driver.find_element(By.ID, "input-firstname")
        first_name.send_keys(name)
        
    def fill_field_last_name(self, name) -> None:
        last_name = self.driver.find_element(By.ID, "input-lastname")
        last_name.send_keys(name)
        
    def fill_field_email(self, email) -> None:
        email_field = self.driver.find_element(By.ID, "input-email")
        email_field.send_keys(email)
        
    def fill_field_telephone(self, telephone) -> None:
        telephone_field = self.driver.find_element(By.ID, "input-telephone")
        telephone_field.send_keys(telephone)
        
    def fill_field_password(self, password) -> None:
        password_field = self.driver.find_element(By.ID, "input-password")
        password_field.send_keys(password)
        
    def fill_field_confirm_password(self, password) -> None:
        password_field = self.driver.find_element(By.ID, "input-confirm")
        password_field.send_keys(password)
        
    def select_newsletter(self) -> None:
        newsletter_field = self.driver.find_element(By.XPATH, '//*[@id="content"]/form/fieldset[3]/div/div/div[1]/label')
        newsletter_field.click()
        
    def select_terms(self) -> None:
        terms_field = self.driver.find_element(By.XPATH, '//*[@id="content"]/form/div/div/div/label')
        terms_field.click()
        
    def select_continue_button(self) -> None:
        continue_field = self.driver.find_element(By.XPATH, '//*[@id="content"]/form/div/div/input')
        continue_field.click()

        
    def run_all(self, first_name, second_name, email, telephone, password,) -> None:

        self.fill_field_name(first_name)
        self.fill_field_last_name(second_name)
        self.fill_field_email(email)
        self.fill_field_telephone(telephone)
        self.fill_field_password(password)
        self.fill_field_confirm_password(password)
        self.select_newsletter()
        self.select_terms()
        self.select_continue_button()
        print(f"Cadastro do usuario {first_name} {second_name} realizado com sucesso!")
        self.driver.quit()

# %% [markdown]
# ### Agora que criamos todas as funções e métodos, vamos executar tudo de uma só vez.

# %%
registros = gera_dados(num_registros=3)
data_to_excel(registros)

for valor in registros:
    try:
        bot = EcommerceBot()
        bot.run_all(
            first_name=valor['first_name'],
            second_name=valor['second_name'],
            email=valor['email'],
            telephone=valor['telephone'],
            password=valor['password']
        )
    except Exception as e:
        print(f"Não foi possivel realizar o cadastro do usuario {valor['first_name']} {valor['second_name']}\nErro:{e}")

# %% [markdown]
# # **Referências**

# %% [markdown]
# ## [Selenium](https://www.browserstack.com/selenium#:~:text=Selenium%20is%20an%20open%2Dsource,%2C%20and%20C%23%2C%20among%20others.)
# ## [Installation](https://selenium-python.readthedocs.io/installation.html#installing-python-bindings-for-selenium)
# ## [official documentation](https://www.selenium.dev/documentation/en/webdriver/driver_requirements/)
# ## [How To Automate Filling In Web Forms With Python Using Selenium](https://www.lambdatest.com/blog/how-to-automate-filling-in-web-forms-with-python-using-selenium/)
# ---
